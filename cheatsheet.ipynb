# %% [markdown]
# ## Packages

# %% [markdown]
# ### Install packages

# %%
# %sh
pip install adal
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: adal in /databricks/python3/lib/python3.7/site-packages (1.2.7)
# Requirement already satisfied: python-dateutil&lt;3,&gt;=2.1.0 in /databricks/python3/lib/python3.7/site-packages (from adal) (2.8.1)
# Requirement already satisfied: PyJWT&lt;3,&gt;=1.0.0 in /databricks/python3/lib/python3.7/site-packages (from adal) (2.4.0)
# Requirement already satisfied: requests&lt;3,&gt;=2.0.0 in /databricks/python3/lib/python3.7/site-packages (from adal) (2.22.0)
# Requirement already satisfied: cryptography&gt;=1.1.0 in /databricks/python3/lib/python3.7/site-packages (from adal) (2.8)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.7/site-packages (from python-dateutil&lt;3,&gt;=2.1.0-&gt;adal) (1.14.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,&lt;1.26,&gt;=1.21.1 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;adal) (1.25.8)
# Requirement already satisfied: idna&lt;2.9,&gt;=2.5 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;adal) (2.8)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;adal) (2020.6.20)
# Requirement already satisfied: chardet&lt;3.1.0,&gt;=3.0.2 in /usr/lib/python3/dist-packages (from requests&lt;3,&gt;=2.0.0-&gt;adal) (3.0.4)
# Requirement already satisfied: cffi!=1.11.3,&gt;=1.8 in /databricks/python3/lib/python3.7/site-packages (from cryptography&gt;=1.1.0-&gt;adal) (1.14.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.7/site-packages (from cffi!=1.11.3,&gt;=1.8-&gt;cryptography&gt;=1.1.0-&gt;adal) (2.19)
# WARNING: You are using pip version 20.0.2; however, version 22.1.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python3.7 -m pip install --upgrade pip&#39; command.
# </div>

# %% [markdown]
# ### Download packages from github

# %%
! git clone https://github.com/YousefGh/kmeans-feature-importance.git
# Load python functions
exec(open('./kmeans-feature-importance/kmeans_interp/kmeans_feature_imp.py', encoding='utf-8').read())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Import packages

# %%
import os
import re
import numpy as np
import pandas as pd
import datetime

import pyspark.sql.functions as pyssql_func
import pyspark.sql.types as pyssql_types
import pyspark.ml.feature as pysml_feature 
import pyspark.sql.window as pyssql_window
import pyspark
import delta.tables as delta_tbl
import shutil
import adal

import re
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Arguments Setup

# %%
# %run
/path_to_where_you_placed_your_config_notebook/config

# %%
# get the arguments commonly used from your config notebook
user_email_path = config.get('user_email_path') 

# custom arguments
project_name = 'testing'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Arguments for scheduled jobs
# add argument widgets
dbutils.widgets.text("data_month", "")
# # remove argument widgets
# dbutils.widgets.removeAll()

# Get arguments
if dbutils.widgets.get("data_month") == "": # Check if exist
  dbutils.notebook.exit("Please add an argument of a process, data_month")
else: 
  data_month = dbutils.widgets.get("data_month")
# Out:
# Please add an argument of a process, data_month

# %% [markdown]
# ## Install customized functions

# %%
# %run
/path_to_where_you_placed_your_functions/db_connection

# %% [markdown]
# ## Connection to database

# %%
# Testing
pushdown_query = "db_schema.db_tableA"
tableA = spark.read\
.jdbc(
    url = db_access.jdbcUrl, 
    table=pushdown_query, 
    properties = db_access.connectionProperties
)\
.select(
    pyssql_func.trim('original_colA').alias('new_colA'),
    pyssql_func.trim('original_colB').alias('new_colB')
).limit(10).dropDuplicates()
display(tableA)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AA_UID</th><th>ALPHA_ID</th></tr></thead><tbody><tr><td>00000032120B542752464790D434B58AD2F16D9093DFF1F5F5E96EBBE59003AB</td><td>17294044</td></tr><tr><td>000006DE941AC89B2DE4C19AE8E34F2FD2912A0910C3D8F2984161752A8D818D</td><td>13837911</td></tr><tr><td>000008FB9B4D7BB5D992A49D7D434B5A5A8EC260F0AA20D86951D0E4326CE726</td><td>04090272</td></tr><tr><td>00000AD348E8E7E93F1A7E0E4FC32D1A05CC3BA52313EE8BF4A5BD9DEFC80403</td><td>02171747</td></tr><tr><td>00000BF40D56E8BDB77D84AD24282950A33A4C7CDB9FF7018B327678A7F4B4DC</td><td>01644045</td></tr><tr><td>00000C6336F40932303917D564099BCD82E341A3F5B1919C6EA1A272937C1B58</td><td>00623039</td></tr><tr><td>00000C6A767FCA4C24FCCD1A045EEB44705D947527520171A0675120D57A8872</td><td>01907945</td></tr><tr><td>00000E385A0924D4DBD7725856C29E4A9D403F2EABEB8DA7D11C82A60D2A50FF</td><td>01433646</td></tr><tr><td>00000F15BD7CD0777527781F5B80DE495F6FD46361CB548E874B6B810AE577FA</td><td>02317627</td></tr><tr><td>00000F788A2D554998AEA1412EAE67096C4D9D148F943593834AEF71FC19FCC8</td><td>03885064</td></tr></tbody></table></div>

# %% [markdown]
# # Directory

# %%
# create dir for project
project_dir = f'dbfs:/FileStore/{user_email_path}/Project/{project_name}'
upload_path = f'{project_dir}/upload/'
download_path = f'{project_dir}/download/'
input_path = f'{project_dir}/input/'
output_path = f'{project_dir}/output/'

dbutils.fs.mkdirs(upload_path)
dbutils.fs.mkdirs(download_path)
dbutils.fs.mkdirs(input_path)
dbutils.fs.mkdirs(output_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: True</div>

# %% [markdown]
# # Common util

# %% [markdown]
# ### List Directory

# %%
display(dbutils.fs.ls(f'dbfs:/FileStore/{user_email_path}/Project/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/shared_uploads/carrie-sc.lo@aia.com/Project/HotMob/</td><td>HotMob/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/shared_uploads/carrie-sc.lo@aia.com/Project/digital_wellness.csv</td><td>digital_wellness.csv</td><td>5804975</td></tr><tr><td>dbfs:/FileStore/tables/shared_uploads/carrie-sc.lo@aia.com/Project/testing/</td><td>testing/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### Copy Files

# %%
dbutils.fs.cp(
    f'{upload_path}/tableA.csv',
    f'{input_path}/tableA.csv',
    True
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: True</div>

# %% [markdown]
# ### Move Files

# %%
dbutils.fs.mv(
    f{upload_path}/tableA.csv',
    f'{output_path}/tableA.csv',
    True
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: True</div>

# %% [markdown]
# ### Read files

# %%
# read pickle
df = pd.read_pickle(re.sub(':', '', f'/{input_path}/tableA.pkl', compression = 'gzip'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4224878950556190&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-green-fg">import</span> pandas <span class="ansi-green-fg">as</span> pd
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">import</span> re
# <span class="ansi-green-fg">----&gt; 4</span><span class="ansi-red-fg"> </span>norm_df <span class="ansi-blue-fg">=</span> pd<span class="ansi-blue-fg">.</span>read_pickle<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;/&#39;</span><span class="ansi-blue-fg">+</span> re<span class="ansi-blue-fg">.</span>sub<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;:&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;&#39;</span><span class="ansi-blue-fg">,</span> input_path<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">+</span> <span class="ansi-blue-fg">&#39;/norm_data.pkl&#39;</span><span class="ansi-blue-fg">,</span> compression <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;gzip&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;input_path&#39; is not defined</div>

# %%
# Using spark to read csv
df = spark.read.format('csv').option('header', 'true').option('delimiter', '\t').load(f'/mnt/data_folder/*/*').limit(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Read data through Hive
from pyspark.sql import SparkSession, HiveContext,DataFrameWriter
from pyspark import SparkContext, SparkConf
conf = SparkConf() #Declare spark conf variable\
conf.setAppName("Read-and-write-data-to-Hive-table-spark")
sc = SparkContext.getOrCreate(conf=conf)
#Instantiate hive context class to get access to the hive sql method
hc = HiveContext(sc)
hive_context= HiveContext(sc)

table_path = 'db_schema.db_tableA'
df = hive_context.sql(("select * from {}").format(table_path))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Convert to pandas DF
df = df.toPandas()

# %% [markdown]
# ### Write files

# %%
# save spark df file
spark_df.coalesce(1).write.mode('overwrite').format('csv').save(f'{output_path}/spark_df', header='true')

# %%
# save csv
tableA.to_csv(re.sub(':', '', f'/{output_path}/tableA.csv'), index=False)
# save pickle
tableA.to_pickle(re.sub(':', '', f'/{output_path}/tableA.pkl'))

# %%
# zip the whole directory
import shutil
sourcePath = re.sub(':', '', f'/{project_dir}')
filename = 'project_zip'
zipPath = f'./{filename}'
shutil.make_archive(zipPath, 'zip', sourcePath)
# os.listdir('.')
shutil.move(f'{filename}.zip', f'{sourcePath}/{filename}.zip')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: &#39;/dbfs/FileStore/tables/shared_uploads/carrie-sc.lo@aia.com/Project/testing/project_zip.zip&#39;</div>

# %% [markdown]
# ### Delete file

# %%
dbutils.fs.rm("dbfs:/FileStore/your_email@company.com/Project/testing/project_zip.zip",True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: True</div>

# %% [markdown]
# # Download file to local laptop
# https://xxxxxxxxxxxxxxxxxxxx.azuredatabricks.net/files/your_email@company.com/Project/testing/project_zip.zip
